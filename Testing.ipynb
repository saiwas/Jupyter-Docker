# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
df=pd.read_csv('restaurants.csv', usecols=[1,2,3,4])
pd.set_option('display.max_rows', df.shape[0]+1)
df.columns=["店面", "链接", "类型", "地址"]
df
# Out:
#                                店面  \
# 0                         好旺角粥麵專家
# 1                            留園雅敘
# 2                             Vea
# 3                              豫園
# 4                           Épure
# 5                             新福記
# 6                        添好運 (北角)
# 7                              德記
# 8                             彭慶記
# 9                 New Punjab Club
# 10                        呇 (尖沙咀)
# 11                            文華廳
# 12                           好湯好麵
# 13                              潤
# 14         Brass Spoon (Wan Chai)
# 15                            大榮華
# 16                        L'Envol
# 17                           坤記糕品
# 18                        明閣 (旺角)
# 19                       唐人館 (中環)
# 20                             柏屋
# 21                          富小路山岸
# 22                   麵鮮醬油房周月(鰂魚涌)
# 23                     豆漿大王 (新蒲崗)
# 24                            彤福軒
# 25                      唐人館 (尖沙咀)
# ...

# %%
df.groupby("类型").count()
# Out:
#          店面  链接  地址
# 类型
# 京菜, 京菜    1   1   1
# 創新菜       7   7   7
# 印尼菜       1   1   1
# 印度菜       3   3   3
# 台州菜       1   1   1
# 台灣菜       2   2   2
# 壽司        3   3   3
# 天婦羅       1   1   1
# 客家菜       1   1   1
# 寧波菜       1   1   1
# 峇里菜       1   1   1
# 川菜        4   4   4
# 意大利菜      9   9   9
# 扒房        2   2   2
# 拉丁美洲菜     1   1   1
# 拉麵        3   3   3
# 斯堪的納維亞菜   1   1   1
# 新疆菜       1   1   1
# 日本菜       8   8   8
# 星馬菜       1   1   1
# 時尚中國菜     1   1   1
# 時尚歐陸菜     6   6   6
# 時尚法國菜     9   9   9
# 法國菜       2   2   2
# 泰國菜       3   3   3
# 浙江菜       1   1   1
# 海鮮        7   7   7
# 湘菜        1   1   1
# 滬菜        6   6   6
# 滬菜, 滬菜    1   1   1
# 潮州菜       3   3   3
# 燒味        5   5   5
# 燒烤        1   1   1
# 瑞士菜       2   2   2
# 秘魯菜       1   1   1
# 粥麵        5   5   5
# 粵菜       56  56  56
# 素食        1   1   1
# 美國意大利菜    1   1   1
# 街頭小吃     22  22  22
# 越南菜       2   2   2
# 鐵板燒       1   1   1
# 閩菜        2   2   2
# 陝西菜       1   1   1
# ...
